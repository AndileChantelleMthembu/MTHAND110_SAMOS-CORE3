# %% [markdown]
# # E2 Exercise Loading and visualizing data from flat files (using AI)
# In this exercise I will use Nitpicker ascii file, containing CTD DATA

# %% [markdown]
# # Part 1 - Flat data and headers

# %%
import pandas as pd
file_path = r"C:\Users\andilecm\Downloads\SAMOSCORE3\MTHAND110_SAMOS-CORE3\for_nitpicker.dat"

df.columns  = [ "Date", "Time", "Depth", "Temperature", "Salinity (psu"]

# %%
import os 

print(os.getcwd())
# Out:
# C:\Users\andilecm\Downloads\SAMOSCORE3\MTHAND110_SAMOS-CORE3

# %%
df.head()
# Out:
#          Date   Time  Depth  Temperature  Salinity
# 0  11/29/2008  06:52      5        28.97     35.21
# 1  11/29/2008  06:52      6        28.98     35.21
# 2  11/29/2008  06:52      7        28.99     35.21
# 3  11/29/2008  06:52      8        28.96     35.21
# 4  11/29/2008  06:52      9        28.99     35.21

# %% [markdown]
# # Part 2- Profiles

# %%
def ddmm2dd(ddmm):
    thedeg = np.floor(ddmm/100.)     
    themin = (ddmm-thedeg*100.)/60.     
    return thedeg+themin

# %%
print(df.columns)
# Out:
# Index(['Date', 'Time', 'Depth', 'Temperature', 'Salinity'], dtype='str')

# %%
print(os.getcwd())
# Out:
# C:\Users\andilecm\Downloads\SAMOSCORE3\MTHAND110_SAMOS-CORE3
